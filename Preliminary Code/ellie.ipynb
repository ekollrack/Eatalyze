# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
food = pd.read_excel("food.xlsx", sheet_name="food")

food.head()
# Out:
#      Category               Description  Nutrient Data Bank Number  \
# 0      BUTTER          BUTTER,WITH SALT                       1001
# 1      BUTTER  BUTTER,WHIPPED,WITH SALT                       1002
# 2  BUTTER OIL      BUTTER OIL,ANHYDROUS                       1003
# 3      CHEESE               CHEESE,BLUE                       1004
# 4      CHEESE              CHEESE,BRICK                       1005
#
#    carbohydrate  cholesterol  fiber  kilocalories  protein  sugar  water  \
# 0          0.06          215    0.0           717     0.85   0.06  15.87
# 1          0.06          219    0.0           717     0.85   0.06  15.87
# 2          0.00          256    0.0           876     0.28   0.00   0.24
# 3          2.34           75    0.0           353    21.40   0.50  42.41
# 4          2.79           94    0.0           371    23.24   0.51  41.11
#
#    monosaturated_fat  polysaturated_fat  saturated_fat  \
# 0             21.021              3.043         51.368
# 1             23.426              3.012         50.489
# 2             28.732              3.694         61.924
# 3              7.778              0.800         18.669
# 4              8.598              0.784         18.764
#
#    first_household_weight first_household_weight_description  \
# 0                  227.00                              1 cup
# 1                  151.00                              1 cup
# 2                  205.00                              1 cup
# 3                   28.35                               1 oz
# 4                  132.00                       1 cup, diced
#
#    second_household_weight second_household_weight_description  sodium
# 0                       14                              1 tbsp     576
# 1                        9                              1 tbsp     827
# 2                       13                              1 tbsp       2
# 3                       17                        1 cubic inch    1395
# 4                      113                     1 cup, shredded     560

# %%
X = food.drop('target_variable', axis=1)
y = food['target_variable']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=26)

rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)
rf_classifier.fit(X_train, y_train)

predictions = rf_classifier.predict(X_test)
accuracy = accuracy_score(y_test, predictions)
print(f"Accuracy: {accuracy}")
